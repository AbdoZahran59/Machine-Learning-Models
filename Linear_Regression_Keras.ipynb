# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import boston_housing
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Load the Boston Housing dataset
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

# Standardize the data
scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
test_data = scaler.transform(test_data)

# Define the neural network model
model = Sequential([
    Dense(64, activation='relu', input_shape=(train_data.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model.fit(train_data, train_targets, epochs=50, batch_size=1, validation_split=0.2, verbose=2)

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate(test_data, test_targets, verbose=0)
print(f"\nMean Absolute Error on Test Set: {test_mae}")

# Make predictions on the test set
test_predictions = model.predict(test_data)

# Create a DataFrame to display actual prices and predicted prices
results_df = pd.DataFrame({
    'Actual Price': test_targets.flatten(),
    'Predicted Price': test_predictions.flatten()
})

# Display the DataFrame
print(results_df)
# Out:
# Epoch 1/50
# 323/323 - 4s - loss: 191.9548 - mae: 10.2860 - val_loss: 38.5439 - val_mae: 4.2441 - 4s/epoch - 14ms/step
# Epoch 2/50
# 323/323 - 1s - loss: 26.6594 - mae: 3.4059 - val_loss: 17.7816 - val_mae: 2.9718 - 1s/epoch - 4ms/step
# Epoch 3/50
# 323/323 - 1s - loss: 18.1341 - mae: 2.7903 - val_loss: 13.2764 - val_mae: 2.7351 - 700ms/epoch - 2ms/step
# Epoch 4/50
# 323/323 - 1s - loss: 14.6935 - mae: 2.6257 - val_loss: 13.3136 - val_mae: 2.8778 - 720ms/epoch - 2ms/step
# Epoch 5/50
# 323/323 - 1s - loss: 13.3746 - mae: 2.4836 - val_loss: 11.2616 - val_mae: 2.6854 - 676ms/epoch - 2ms/step
# Epoch 6/50
# 323/323 - 1s - loss: 12.1676 - mae: 2.4549 - val_loss: 11.4658 - val_mae: 2.5258 - 721ms/epoch - 2ms/step
# Epoch 7/50
# 323/323 - 1s - loss: 11.3868 - mae: 2.3071 - val_loss: 10.3368 - val_mae: 2.3959 - 753ms/epoch - 2ms/step
# Epoch 8/50
# 323/323 - 1s - loss: 11.4611 - mae: 2.3924 - val_loss: 11.7988 - val_mae: 2.6166 - 811ms/epoch - 3ms/step
# Epoch 9/50
# 323/323 - 1s - loss: 10.2961 - mae: 2.2519 - val_loss: 12.1093 - val_mae: 2.5819 - 985ms/epoch - 3ms/step
# Epoch 10/50
# 323/323 - 1s - loss: 9.8051 - mae: 2.2136 - val_loss: 13.5488 - val_mae: 2.6785 - 1s/epoch - 4ms/step
# Epoch 11/50
# 323/323 - 1s - loss: 9.8256 - mae: 2.2219 - val_loss: 22.2776 - val_mae: 3.1824 - 1s/epoch - 4ms/step
# Epoch 12/50
# 323/323 - 1s - loss: 9.9784 - mae: 2.2832 - val_loss: 12.2761 - val_mae: 2.6080 - 880ms/epoch - 3ms/step
# Epoch 13/50
# 323/323 - 1s - loss: 9.0698 - mae: 2.1005 - val_loss: 15.6490 - val_mae: 2.7749 - 820ms/epoch - 3ms/step
# Epoch 14/50
# 323/323 - 1s - loss: 9.5573 - mae: 2.1921 - val_loss: 12.5316 - val_mae: 2.6039 - 806ms/epoch - 2ms/step
# Epoch 15/50
# 323/323 - 1s - loss: 8.8858 - mae: 2.1063 - val_loss: 16.9667 - val_mae: 2.8636 - 979ms/epoch - 3ms/step
# Epoch 16/50
# 323/323 - 1s - loss: 7.9715 - mae: 2.1264 - val_loss: 12.7888 - val_mae: 2.6796 - 840ms/epoch - 3ms/step
# Epoch 17/50
# 323/323 - 1s - loss: 8.1032 - mae: 1.9719 - val_loss: 18.1331 - val_mae: 3.0105 - 769ms/epoch - 2ms/step
# Epoch 18/50
# 323/323 - 1s - loss: 8.1147 - mae: 2.0158 - val_loss: 14.9139 - val_mae: 2.6290 - 756ms/epoch - 2ms/step
# Epoch 19/50
# 323/323 - 1s - loss: 8.1091 - mae: 1.9973 - val_loss: 13.3712 - val_mae: 2.6932 - 822ms/epoch - 3ms/step
# Epoch 20/50
# 323/323 - 1s - loss: 7.5097 - mae: 1.9275 - val_loss: 16.1426 - val_mae: 2.8550 - 719ms/epoch - 2ms/step
# Epoch 21/50
# 323/323 - 1s - loss: 7.9082 - mae: 1.9878 - val_loss: 18.3696 - val_mae: 2.8743 - 752ms/epoch - 2ms/step
# Epoch 22/50
# 323/323 - 1s - loss: 7.1823 - mae: 1.8956 - val_loss: 11.9554 - val_mae: 2.5399 - 786ms/epoch - 2ms/step
# Epoch 23/50
# 323/323 - 1s - loss: 7.3461 - mae: 1.9376 - val_loss: 13.9495 - val_mae: 2.7399 - 1s/epoch - 3ms/step
# Epoch 24/50
# 323/323 - 1s - loss: 7.1449 - mae: 1.8658 - val_loss: 11.2642 - val_mae: 2.3947 - 1s/epoch - 4ms/step
# Epoch 25/50
# 323/323 - 1s - loss: 7.4146 - mae: 1.9413 - val_loss: 13.2008 - val_mae: 2.5025 - 1s/epoch - 4ms/step
# Epoch 26/50
# 323/323 - 1s - loss: 7.2082 - mae: 1.9331 - val_loss: 13.4478 - val_mae: 2.5279 - 933ms/epoch - 3ms/step
# Epoch 27/50
# 323/323 - 1s - loss: 7.0189 - mae: 1.8239 - val_loss: 13.1369 - val_mae: 2.4716 - 837ms/epoch - 3ms/step
# Epoch 28/50
# 323/323 - 1s - loss: 6.8853 - mae: 1.8140 - val_loss: 12.2651 - val_mae: 2.5531 - 845ms/epoch - 3ms/step
# Epoch 29/50
# 323/323 - 1s - loss: 6.5514 - mae: 1.7502 - val_loss: 13.6837 - val_mae: 2.5133 - 849ms/epoch - 3ms/step
# Epoch 30/50
# 323/323 - 1s - loss: 6.9241 - mae: 1.8044 - val_loss: 16.6257 - val_mae: 2.8903 - 820ms/epoch - 3ms/step
# Epoch 31/50
# 323/323 - 1s - loss: 6.1160 - mae: 1.8042 - val_loss: 10.1885 - val_mae: 2.4084 - 740ms/epoch - 2ms/step
# Epoch 32/50
# 323/323 - 1s - loss: 5.9775 - mae: 1.7271 - val_loss: 16.6335 - val_mae: 2.8080 - 783ms/epoch - 2ms/step
# Epoch 33/50
# 323/323 - 1s - loss: 6.3373 - mae: 1.7734 - val_loss: 11.6128 - val_mae: 2.4195 - 767ms/epoch - 2ms/step
# Epoch 34/50
# 323/323 - 1s - loss: 6.1926 - mae: 1.7177 - val_loss: 12.7043 - val_mae: 2.6359 - 741ms/epoch - 2ms/step
# Epoch 35/50
# 323/323 - 1s - loss: 5.7773 - mae: 1.6791 - val_loss: 16.1835 - val_mae: 2.9024 - 644ms/epoch - 2ms/step
# Epoch 36/50
# 323/323 - 1s - loss: 5.8497 - mae: 1.7149 - val_loss: 11.2749 - val_mae: 2.4411 - 716ms/epoch - 2ms/step
# Epoch 37/50
# 323/323 - 1s - loss: 5.7756 - mae: 1.7101 - val_loss: 9.9177 - val_mae: 2.3398 - 1s/epoch - 3ms/step
# Epoch 38/50
# 323/323 - 1s - loss: 5.3132 - mae: 1.6299 - val_loss: 16.4592 - val_mae: 2.5857 - 1s/epoch - 3ms/step
# Epoch 39/50
# 323/323 - 1s - loss: 5.9920 - mae: 1.7294 - val_loss: 12.3550 - val_mae: 2.5593 - 1s/epoch - 3ms/step
# Epoch 40/50
# 323/323 - 1s - loss: 5.7796 - mae: 1.6646 - val_loss: 13.1524 - val_mae: 2.5152 - 1s/epoch - 3ms/step
# Epoch 41/50
# 323/323 - 1s - loss: 5.5352 - mae: 1.6832 - val_loss: 11.8390 - val_mae: 2.4480 - 630ms/epoch - 2ms/step
# Epoch 42/50
# 323/323 - 1s - loss: 5.4334 - mae: 1.6221 - val_loss: 12.4872 - val_mae: 2.4903 - 709ms/epoch - 2ms/step
# Epoch 43/50
# 323/323 - 1s - loss: 5.6310 - mae: 1.7196 - val_loss: 12.8023 - val_mae: 2.5375 - 712ms/epoch - 2ms/step
# Epoch 44/50
# 323/323 - 1s - loss: 5.5727 - mae: 1.6755 - val_loss: 10.1060 - val_mae: 2.3180 - 690ms/epoch - 2ms/step
# Epoch 45/50
# 323/323 - 1s - loss: 5.2241 - mae: 1.6157 - val_loss: 13.8941 - val_mae: 2.6423 - 695ms/epoch - 2ms/step
# Epoch 46/50
# 323/323 - 1s - loss: 4.3941 - mae: 1.4988 - val_loss: 12.5210 - val_mae: 2.6257 - 653ms/epoch - 2ms/step
# Epoch 47/50
# 323/323 - 1s - loss: 5.1761 - mae: 1.6305 - val_loss: 10.9415 - val_mae: 2.3957 - 655ms/epoch - 2ms/step
# Epoch 48/50
# 323/323 - 1s - loss: 4.9654 - mae: 1.6074 - val_loss: 12.1526 - val_mae: 2.5529 - 797ms/epoch - 2ms/step
# Epoch 49/50
# 323/323 - 1s - loss: 4.8633 - mae: 1.6002 - val_loss: 10.5259 - val_mae: 2.3449 - 706ms/epoch - 2ms/step
# Epoch 50/50
# 323/323 - 1s - loss: 4.2425 - mae: 1.4855 - val_loss: 10.7342 - val_mae: 2.4658 - 712ms/epoch - 2ms/step
#
# Mean Absolute Error on Test Set: 2.6614794731140137
# 4/4 [==============================] - 0s 3ms/step
#      Actual Price  Predicted Price
# 0             7.2         9.102688
# 1            18.8        18.907354
# 2            19.0        20.767052
# 3            27.0        31.680649
# 4            22.2        25.833742
# ..            ...              ...
# 97           21.9        42.579090
# 98           24.1        24.857494
# 99           50.0        47.898045
# 100          26.7        29.107580
# 101          25.0        19.635157
#
# [102 rows x 2 columns]
